# %% [markdown]
# ## TCP Reno Logarithmic Pacing w/ 0.4 as back off beta

# %%
from experiments.max_flightsize.scatter_plot.plotting import plot_ssthresh_w_backoff
from experiments.steady_ssthresh.teacup_data_processing import get_ssthresh_from_files

first, second = get_ssthresh_from_files("data/exp_20260223-163731")

queues = [q for q in range(5, 255, 5)]

plot_ssthresh_w_backoff(queues, 125, first, second, "ssthresh Reno logarithmic pacing, beta = 0.4", color="blue", save=True, backoff=0.4)

# %% [markdown]
# ### Comments
#
# - Seems like for small queues (< 85 packets), we still see double back offs
# - There seems to be some correlation between when double back offs stop appearing, and when normal Reno usually reaches BDP + queue
# -

# %%
from experiments.steady_ssthresh.teacup_data_processing import get_ssthresh_from_files

first, second = get_ssthresh_from_files("data/exp_20260223-123832")

queues = [q for q in range(5, 255, 5)]

plot_ssthresh_w_backoff(queues, 125, first, second, "ssthresh Reno logarithmic pacing, beta = 0.35", color="blue", save=True, backoff=0.35)

# %%
from experiments.steady_ssthresh.teacup_data_processing import get_ssthresh_from_files

first, second = get_ssthresh_from_files("data/exp_20260223-174115")

queues = [q for q in range(5, 255, 5)]

plot_ssthresh_w_backoff(queues, 125, first, second, "ssthresh Reno logarithmic pacing, beta = 0.25", color="blue", save=True, backoff=0.25)

# %%
from experiments.steady_ssthresh.teacup_data_processing import get_ssthresh_from_files

first, second = get_ssthresh_from_files("data/exp_20260223-143950")

queues = [q for q in range(5, 255, 5)]

plot_ssthresh_w_backoff(queues, 125, first, second, "ssthresh Reno logarithmic pacing, beta = 0.3", color="blue", save=True, backoff=0.3)

# %%
from experiments.steady_ssthresh.teacup_data_processing import get_ssthresh_from_files

first, second = get_ssthresh_from_files("data/exp_20260302-163825")

queues = [q for q in range(5, 255, 5)]

plot_ssthresh_w_backoff(queues, 125, first, second, "ssthresh Reno logarithmic pacing, beta = 0.5", color="blue", save=True, backoff=0.5, show_double_backoff=True)
