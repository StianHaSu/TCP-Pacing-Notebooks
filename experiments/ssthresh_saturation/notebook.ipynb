# %%
from data_preperation import get_sshthresh_from_file

EXPERIMENT_TIME = "2025-12-12_17:12:03.114461"
SSTHRESH_DIR = "ssthresh"

first, second = get_sshthresh_from_file(EXPERIMENT_TIME + "/" + SSTHRESH_DIR + "/sstresh-queue-5.txt")

print(f"first {first} second {second}")
# Out:
# first ('ssthresh:7', '17:12:15.027381111') second ('ssthresh:8', '17:12:15.759556819')
