# %% [markdown]
# ## Custom pacing x1

# %%
from data_preperation import get_queue_ssthresh_rtt, get_last_queue_ssthresh_rtt
from plotting import plot_ssthresh_and_queue_size

queue, ssthresh, rtts = get_last_queue_ssthresh_rtt("6.12.1037+-2025-12-15_19:58:52.923656")
plot_ssthresh_and_queue_size(queue, ssthresh, rtts)

# %% [markdown]
# ## Custom pacing x5

# %%
queue, ssthresh, rtts = get_last_queue_ssthresh_rtt("6.12.1037+-2025-12-15_11:37:00.839135")
plot_ssthresh_and_queue_size(queue, ssthresh, rtts)

# %% [markdown]
# ## Custom pacing x8

# %%
# With htb enabled and correct queue
queue, ssthresh, rtts = get_queue_ssthresh_rtt("6.12.1037+-2025-12-15_19:47:26.564534")
plot_ssthresh_and_queue_size(queue, ssthresh, rtts)

# %% [markdown]
# ## Reno without pacing

# %%
queue, ssthresh, rtts = get_last_queue_ssthresh_rtt("6.12.10-2025-12-15_19:05:48.638728")
plot_ssthresh_and_queue_size(queue, ssthresh, rtts)

# %% [markdown]
# ## Reno with pacing

# %%
queue, ssthresh, rtts = get_last_queue_ssthresh_rtt("6.12.10-2025-12-15_18:50:51.715707")
plot_ssthresh_and_queue_size(queue, ssthresh, rtts)

# %% [markdown]
# ## Cubic quick ack
# ### No pacing

# %%
queue, ssthresh, rtts = get_last_queue_ssthresh_rtt("6.12.10-2025-12-15_12:28:20.453648")
plot_ssthresh_and_queue_size(queue, ssthresh, rtts)

# %% [markdown]
# ## With pacing

# %%
queue, ssthresh, rtts = get_last_queue_ssthresh_rtt("6.12.10-2025-12-15_12:35:53.122954")
plot_ssthresh_and_queue_size(queue, ssthresh, rtts)

# %% [markdown]
# ## Cubic custom x8
# ### With quick ack

# %%
queue, ssthresh, rtts = get_last_queue_ssthresh_rtt("6.12.1037+-2025-12-15_15:29:14.541643")
plot_ssthresh_and_queue_size(queue, ssthresh, rtts)
