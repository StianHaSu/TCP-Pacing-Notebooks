# %%
from data_preperation import get_queue_ssthresh_rtt, get_last_queue_ssthresh_rtt
from plotting import plot_ssthresh_and_queue_size

# %% [markdown]
# ## Custom pacing x8

# %%
# With htb enabled and correct queue
queue, ssthresh, rtts, cwnds = get_queue_ssthresh_rtt("6.12.1037+-2026-01-20_17:34:37.052606")
plot_ssthresh_and_queue_size(queue, ssthresh, rtts, cwnds)

# %% [markdown]
# ## Cubic custom x8
