# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from simulation import run_experiments
#       2 import time
#       5 run_experiments(time.now(), [x for x in range(5, 255, 5)], 30, 50)
#
# File ~/Documents/MasterTheisData/experiments/ssthresh_saturation/simulation.py:1
# ----> 1 from mininet.topo import Topo
#       2 from mininet.net import Mininet
#       3 from mininet.link import TCLink
#
# ModuleNotFoundError: No module named 'mininet'
