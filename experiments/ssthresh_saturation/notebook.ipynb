# %% [markdown]
# ## Custom pacing x1
# ### Two queues with queue size

# %%
from data_preperation import get_queue_and_ssthresh
from plotting import plot_ssthresh_and_queue_size

queue, ssthresh = get_queue_and_ssthresh("6.12.1037+-2025-12-15_10:02:43.770813")
plot_ssthresh_and_queue_size(queue, ssthresh)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 from data_preperation import get_queue_and_ssthresh
#       2 from plotting import plot_ssthresh_and_queue_size
# ----> 4 queue, ssthresh = get_queue_and_ssthresh("6.12.1037+-2025-12-15_10:02:43.770813")
#       5 plot_ssthresh_and_queue_size(queue, ssthresh)
#
# File ~/Documents/master/MasterThesisData/experiments/ssthresh_saturation/data_preperation.py:34, in get_queue_and_ssthresh(experiment_time)
#      30 ssthresh = []
#      32 for queue in queues:
#      33     ssthresh.append(
# ---> 34         int(get_sshthresh_from_file(f"{experiment_time}/ssthresh/ssthresh-queue-{queue}.txt")[0][0])
#      35     )
#      37 return queues, ssthresh
#
# File ~/Documents/master/MasterThesisData/experiments/ssthresh_saturation/data_preperation.py:7, in get_sshthresh_from_file(file_name)
# ...

# %% [markdown]
# ## Custom pacing x5

# %%
queue, ssthresh = get_queue_and_ssthresh("6.12.1037+-2025-12-15_10:29:14.338806")
plot_ssthresh_and_queue_size(queue, ssthresh)

# %% [markdown]
# ## Custom pacing x8

# %%
queue, ssthresh = get_queue_and_ssthresh("6.12.1037+-2025-12-15_10:39:44.486166")
plot_ssthresh_and_queue_size(queue, ssthresh)

# %% [markdown]
# ## Reno without pacing

# %%
queue, ssthresh = get_queue_and_ssthresh("6.12.10-2025-12-15_11:06:28.549364")
plot_ssthresh_and_queue_size(queue, ssthresh)

# %% [markdown]
# ## Reno with pacing

# %%
queue, ssthresh = get_queue_and_ssthresh("6.12.10-2025-12-15_11:14:41.553577")
plot_ssthresh_and_queue_size(queue, ssthresh)
