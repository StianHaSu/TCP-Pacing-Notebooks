# %%
from data_preperation import get_sshthresh_from_file
from plotting import plot_ssthresh_and_queue_size

EXPERIMENT_TIME = "2025-12-12_16:17:22.498086"
SSTHRESH_DIR = "ssthresh"

queues = [x for x in range(5, 255, 5)]
ssthresh = []

for queue in queues:
    ssthresh.append(
        int(get_sshthresh_from_file(f"{EXPERIMENT_TIME}/{SSTHRESH_DIR}/sstresh-queue-{queue}.txt")[0][0])
    )

plot_ssthresh_and_queue_size(queues, ssthresh)
