# %% [markdown]
# ### How the pacing is done
# Pacing is enabled in the sender with the command:
# tc qdisc replace dev [h1-eth0] root fq maxrate 10mbit

# %%
import numpy as np

from analysis.utils.plotting import *

# %%
DATA_FILES_BASE_PATH_TOPOLOGY_1 = "../data/topology_one_data/"
GRAPH_CUTOFF = 1000

graphs = [
    GraphConfig("data/exp_20260302-123406_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_100_run_0_zelda_10Ga_router.dmp", 
                "RENO logarithmic pacing", 
                label=None, 
                cutoff=GRAPH_CUTOFF, 
                color="blue", 
                include_acks=False, 
                save_plot=True,
                tick_step_y=10,
                tick_step_x=10,
                start=0,
                end=70
                )
]

plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)

# %% [markdown]
# ## Logarithmic pacing queue = 100 packets BDP = 125 packets

# %%
DATA_FILES_BASE_PATH_TOPOLOGY_1 = "../data/topology_one_data/"
GRAPH_CUTOFF = 1000

graphs = [
    GraphConfig("data/exp_20260227-170609_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_100_run_0_zelda_10Ga_router.dmp", 
                "RENO logarithmic pacing", 
                label=None, 
                cutoff=GRAPH_CUTOFF, 
                color="blue", 
                include_acks=False, 
                save_plot=True,
                tick_step_y=10,
                tick_step_x=5,
                start=100,
                end=150
                )
]

plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)

# %%
#GRAPH_CUTOFF = -1
#graph = GraphConfig("data/exp_20260302-181141_del_15_down_10000mbit_up_10000mbit_aqm_pfifo_tcp_newreno_bs_2500_run_0_zelda_10Ga_router.dmp", 
 #               "RENO logarithmic pacing", 
  #              label=None, 
   #             cutoff=GRAPH_CUTOFF, 
    #            color="blue", 
     #           include_acks=False, 
      #          save_plot=True,
       #         tick_step_y=10000,
        #        tick_step_x=1000)

#plot_packets_from_pcap_file(graph, None, cutoff=GRAPH_CUTOFF, exit_after_ss=False)

# %% [markdown]
# ## No pacing queue = 100 packets BDP = 125 packets

# %%
GRAPH_CUTOFF = 1000

graphs = [
    GraphConfig("data/exp_20260215-161744_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_100_run_0_zelda_10Ga_router.dmp", "RENO no pacing", label=None, cutoff=GRAPH_CUTOFF, color="red", include_acks=False, save_plot=True,
                tick_step_y=10,
                tick_step_x=5,
                start=0,
                end=70),
]

graphs = plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)

# %%
GRAPH_CUTOFF = 150

graph = GraphConfig("data/exp_20260215-161744_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_100_run_0_ganon.dmp", "RENO no pacing", 
                    label=None, 
                    cutoff=GRAPH_CUTOFF, 
                    color="red", 
                    include_acks=False, 
                    save_plot=True,
                    tick_step_y=15, 
                    tick_step_x=20)


plot_packets_from_pcap_file(graph, None, cutoff=GRAPH_CUTOFF)
# Out:
# Total sent packets before third dupack: 895

# %% [markdown]
# ## NewReno default pacing Queue = 100 packets BDP = 125 packets

# %%
GRAPH_CUTOFF = 1000

graphs = [
    GraphConfig("data/exp_20260215-162949_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_100_run_0_ganon.dmp", "RENO default pacing", label=None, cutoff=GRAPH_CUTOFF, color="green", include_acks=False, save_plot=True,
                tick_step_y=10,
                tick_step_x=5,
                start=0,
                end=30)
]

graphs = plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)

# %%
GRAPH_CUTOFF = 150

graph = GraphConfig("data/exp_20260215-162949_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_100_run_0_ganon.dmp", "RENO no pacing", 
                    label=None, 
                    cutoff=GRAPH_CUTOFF, 
                    color="red", 
                    include_acks=False, 
                    save_plot=True,
                    tick_step_y=15, 
                    tick_step_x=20)


plot_packets_from_pcap_file(graph, None, cutoff=GRAPH_CUTOFF)
# Out:
# Total sent packets before third dupack: 887

# %% [markdown]
# ## Logarithmic pacing queue = 250 packets BDP = 125 packets

# %%
GRAPH_CUTOFF = 2000

graphs = [
    GraphConfig("data/exp_20260213-161904_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_250_run_0_ganon.dmp", "RENO logarithmic pacing 250q", label=None, cutoff=GRAPH_CUTOFF, color="blue", include_acks=False, save_plot=True),
]

graphs = plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)
# Out:
# Total sent packets before third dupack: 1494

# %% [markdown]
# ## No pacing queue = 250 packets BDP = 125 packets

# %% [markdown]
# ## Default pacing queue = 250 packets BDP = 125 packets

# %%
GRAPH_CUTOFF = 2000

graphs = [
    GraphConfig("data/exp_20260215-172835_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_250_run_0_ganon.dmp", "RENO logarithmic pacing 250q", label=None, cutoff=GRAPH_CUTOFF, color="blue", include_acks=False, save_plot=True),
]

graphs = plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)
# Out:
# Total sent packets before third dupack: 1493

# %%
from analysis.utils.plotting import *

DATA_FILES_BASE_PATH_TOPOLOGY_1 = "../data/topology_one_data/"
GRAPH_CUTOFF = -1

graphs = [
    GraphConfig("data/exp_20260305-154905_del_15_down_1000mbit_up_1000mbit_aqm_pfifo_tcp_newreno_bs_250_run_0_zelda_10Ga_router.dmp", 
                "RENO logarithmic pacing", 
                label=None, 
                cutoff=GRAPH_CUTOFF, 
                color="blue", 
                include_acks=False, 
                save_plot=True,
                tick_step_y=10000,
                tick_step_x=100,
                start=0,
                end=100000
    )
]

plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)
# Out:
# Total sent packets before third dupack: 1525

# %%
from analysis.utils.plotting import *

DATA_FILES_BASE_PATH_TOPOLOGY_1 = "../data/topology_one_data/"
GRAPH_CUTOFF = -1

graphs = [
    GraphConfig("data/exp_20260305-231449_del_15_down_1000mbit_up_1000mbit_aqm_pfifo_tcp_newreno_bs_250_run_9_zelda_10Ga_router.dmp", 
                "RENO default pacing", 
                label=None, 
                cutoff=GRAPH_CUTOFF, 
                color="blue", 
                include_acks=False, 
                save_plot=True,
                tick_step_y=10,
                tick_step_x=5,
                start=0,
                end=100
    )
]

plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)
# Out:
# Total sent packets before third dupack: 99

# %%
plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)
from analysis.utils.plotting import *

DATA_FILES_BASE_PATH_TOPOLOGY_1 = "../data/topology_one_data/"
GRAPH_CUTOFF = -1

graphs = [
    GraphConfig(
        "exp_20260306-170319_del_15_down_1000mbit_up_1000mbit_aqm_pfifo_tcp_newreno_bs_500_run_7_zelda_10Ga_router.dmp",
        "RENO default pacing",
        label=None,
        cutoff=GRAPH_CUTOFF,
        color="blue",
        include_acks=False,
        save_plot=True,
        tick_step_y=10,
        tick_step_x=5,
        start=0,
        end=300
        )
]

plot_packets_from_pcap_file(graphs[0], None, cutoff=GRAPH_CUTOFF)
# Out:
# Total sent packets before third dupack: 217

# %% [markdown]
# ## No FPU implementation vs with FPU

# %%
GRAPH_CUTOFF = 500

included_data_no_fpu = [
    #GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_1 + "6.12.1036_reno_1m_topology1_30s.pcap", "RENO custom paced x1", #label="Custom x1 no FPU", cutoff=GRAPH_CUTOFF, color="green"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_1 + "6.12.1037_reno_5m_topology1_30s.pcap", "RENO custom paced x5", label="Custom x5 no FPU", cutoff=GRAPH_CUTOFF, color="blue"),
    #GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_1 + "6.12.1037_reno_10m_topology1_30s.pcap", "RENO custom paced x5", #label="Custom x10 no FPU", cutoff=GRAPH_CUTOFF, color="magenta"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_1 + "6.12.1035_reno_5m_topology1_30s.pcap", "RENO custom paced x5", label="Custom x5 with FPU", cutoff=GRAPH_CUTOFF, color="red"),
    #GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_1 + "6.12.1035_reno_10m_topology1_30s.pcap", "RENO custom paced x5", #label="Custom x10 with FPU", cutoff=GRAPH_CUTOFF, color="orange"),
]

graphs_no_fpu = plot_packets_from_pcap_files(included_data_no_fpu, cutoff=GRAPH_CUTOFF, title="Custom pacing with multiplier from 1 to 10")
graphs_mapped_no_fpu = { graph[0].title : graph for graph in graphs_no_fpu }
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 11
#       1 GRAPH_CUTOFF = 500
#       3 included_data_no_fpu = [
#       4     #GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_1 + "6.12.1036_reno_1m_topology1_30s.pcap", "RENO custom paced x1", #label="Custom x1 no FPU", cutoff=GRAPH_CUTOFF, color="green"),
#       5     GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_1 + "6.12.1037_reno_5m_topology1_30s.pcap", "RENO custom paced x5", label="Custom x5 no FPU", cutoff=GRAPH_CUTOFF, color="blue"),
#    (...)
#       8     #GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_1 + "6.12.1035_reno_10m_topology1_30s.pcap", "RENO custom paced x5", #label="Custom x10 with FPU", cutoff=GRAPH_CUTOFF, color="orange"),
#       9 ]
# ---> 11 graphs_no_fpu = plot_packets_from_pcap_files(included_data_no_fpu, cutoff=GRAPH_CUTOFF, title="Custom pacing with multiplier from 1 to 10")
# ...

# %%
GRAPH_CUTOFF = 1000

plot_packets_from_pcap_files(graphs, list(graphs_mapped.values()), cutoff=GRAPH_CUTOFF)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 GRAPH_CUTOFF = 1000
# ----> 3 plot_packets_from_pcap_files(graphs, list(graphs_mapped.values()), cutoff=GRAPH_CUTOFF)
#
# NameError: name 'graphs_mapped' is not defined

# %%
GRAPH_CUTOFF = 10000

plot_packets_from_pcap_files(graphs, list(graphs_mapped.values()), cutoff=GRAPH_CUTOFF)

# %%
GRAPH_CUTOFF = 100

graphs_calculated = [graphs_mapped["RENO default paced"], graphs_mapped["RENO custom paced x10"], graphs_mapped["RENO no pacing"]] 

plot_packets_from_pcap_files(graphs, graphs_calculated, cutoff=GRAPH_CUTOFF)

# %%
GRAPH_CUTOFF = -1

graphs_calculated = [graphs_mapped["RENO default paced"], graphs_mapped["RENO custom paced x10"], graphs_mapped["RENO no pacing"]] 

plot_packets_from_pcap_files(graphs, graphs_calculated, cutoff=GRAPH_CUTOFF)

# %%
GRAPH_CUTOFF = -1

graphs_calculated = [graphs_mapped["RENO default paced"], graphs_mapped["RENO custom paced x10"], graphs_mapped["RENO no pacing"]] 

plot_packets_from_pcap_files(graphs, graphs_calculated, cutoff=GRAPH_CUTOFF)

# %%
GRAPH_CUTOFF = 100

graphs_calculated = [graphs_mapped["RENO default paced"], graphs_mapped["RENO custom paced"], graphs_mapped["RENO custom paced x10"], graphs_mapped["RENO no pacing"]] 

plot_packets_from_pcap_files(graphs, graphs_calculated, cutoff=GRAPH_CUTOFF)

# %%
## Data for topology 3
### Two senders A and B, are connected to a switch S1, S1 is connected to a second switch S1, which is connected to receivers C and D

# %%
GRAPH_CUTOFF = -1

DATA_FILES_BASE_PATH_TOPOLOGY_3 = "../data/topology_three_data/"

topology_three = [
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_1m_topology3_sender1_30s.pcap", "RENO custom paced x1", label="Sender 1 Custom x1", cutoff=GRAPH_CUTOFF, color="red"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_1m_topology3_sender2_30s.pcap", "RENO custom paced x1", label="Sender 2 Custom x1", cutoff=GRAPH_CUTOFF, color="orange"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_5m_topology3_sender1_30s.pcap", "Reno custom paced x5", label="Sender 1 custom x5", cutoff=GRAPH_CUTOFF, color="magenta"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_5m_topology3_sender2_30s.pcap", "Reno custom paced x5", label="Sender 2 custom x5", cutoff=GRAPH_CUTOFF, color="blue"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_nop_topology3_sender1_30s.pcap", "RENO default", label="Sender 1 reno", cutoff=GRAPH_CUTOFF, color="green"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_cubic_nop_topology3_sender1_30s.pcap", "CUBIC default", label="Sender 1 cubic", cutoff=GRAPH_CUTOFF, color="pink"),
]
graphs3 = plot_packets_from_pcap_files(topology_three, cutoff=GRAPH_CUTOFF, title="Topology 3 with senders using same CC approach")

# %%
GRAPH_CUTOFF = -1

DATA_FILES_BASE_PATH_TOPOLOGY_3 = "../data/topology_three_data/"

topology_three_2 = [
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_1m_topology3_sender1_30s.pcap", "Reno custom paced x1 1", label="Sender 1 custom x1", cutoff=GRAPH_CUTOFF, color="magenta"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_5m_topology3_sender1_30s.pcap", "Reno custom paced x5 1", label="Sender 1 custom x5", cutoff=GRAPH_CUTOFF, color="blue"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_10m_topology3_sender1_30s.pcap", "Reno custom paced x10 1", label="Sender 1 custom x10", cutoff=GRAPH_CUTOFF, color="blue"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_cubic_5m_topology3_sender1_30s.pcap", "CUBIC custom paced x5 1", label="Sender 1 cubic x5", cutoff=GRAPH_CUTOFF, color="blue"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_cubic_10m_topology3_sender1_30s.pcap", "CUBIC custom paced x10 1", label="Sender 1 cubic x10", cutoff=GRAPH_CUTOFF, color="blue"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_nop_topology3_sender1_30s.pcap", "RENO default 1", label="Sender 1 reno", cutoff=GRAPH_CUTOFF, color="green"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_cubic_nop_topology3_sender1_30s.pcap", "CUBIC default 1", label="Sender 1 cubic", cutoff=GRAPH_CUTOFF, color="pink"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_paced_topology3_sender1_30s.pcap", "RENO paced 1", label="Sender 1 reno paced", cutoff=GRAPH_CUTOFF, color="yellow"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_cubic_paced_topology3_sender1_30s.pcap", "CUBIC paced 1", label="Sender 1 cubic paced", cutoff=GRAPH_CUTOFF, color="grey"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_bbr_topology3_sender1_30s_3.pcap", "BBR 1", label="Sender 1 bbr", cutoff=GRAPH_CUTOFF, color="black"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_1m_topology3_sender2_30s.pcap", "Reno custom paced x1 2", label="Sender 2 custom x1", cutoff=GRAPH_CUTOFF, color="magenta"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_5m_topology3_sender2_30s.pcap", "Reno custom paced x5 2", label="Sender 2 custom x5", cutoff=GRAPH_CUTOFF, color="purple"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_10m_topology3_sender2_30s.pcap", "Reno custom paced x10 2", label="Sender 2 custom x10", cutoff=GRAPH_CUTOFF, color="purple"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_cubic_5m_topology3_sender2_30s.pcap", "CUBIC custom paced x5 2", label="Sender 2 cubic x5", cutoff=GRAPH_CUTOFF, color="purple"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_cubic_10m_topology3_sender2_30s.pcap", "CUBIC custom paced x10 2", label="Sender 1 cubic x10", cutoff=GRAPH_CUTOFF, color="blue"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_nop_topology3_sender2_30s.pcap", "RENO default 2", label="Sender 2 reno", cutoff=GRAPH_CUTOFF, color="green"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_cubic_nop_topology3_sender2_30s.pcap", "CUBIC default 2", label="Sender 2 cubic", cutoff=GRAPH_CUTOFF, color="pink"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_reno_paced_topology3_sender2_30s.pcap", "RENO paced 2", label="Sender 2 reno paced", cutoff=GRAPH_CUTOFF, color="yellow"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_cubic_paced_topology3_sender2_30s.pcap", "CUBIC paced 2", label="Sender 2 cubic paced", cutoff=GRAPH_CUTOFF, color="grey"),
    GraphConfig(DATA_FILES_BASE_PATH_TOPOLOGY_3 + "6.12.1035_bbr_topology3_sender2_30s_3.pcap", "BBR 2", label="Sender 2 bbr", cutoff=GRAPH_CUTOFF, color="black"),
]
graphs4 = plot_packets_from_pcap_files(topology_three_2, cutoff=GRAPH_CUTOFF, title="Topology 3 with senders using same CC approach")

# %%
graphs_mapped = { graph[0].title : graph for graph in graphs4}  
graphs_calculated = [graphs_mapped["RENO paced 1"], graphs_mapped["RENO paced 2"], graphs_mapped["CUBIC paced 1"], graphs_mapped["CUBIC paced 2"]] 

plot_packets_from_pcap_files(graphs4, graphs_calculated, cutoff=GRAPH_CUTOFF)

# %%
GRAPH_CUTOFF = -1

graphs_mapped = { graph[0].title : graph for graph in graphs4}  
graphs_calculated = [graphs_mapped["BBR 1"], graphs_mapped["BBR 2"], graphs_mapped["CUBIC custom paced x10 1"], graphs_mapped["CUBIC custom paced x10 2"]] 

plot_packets_from_pcap_files(graphs4, graphs_calculated, cutoff=GRAPH_CUTOFF)

# %%
import math
import matplotlib.pyplot as plt

LOG2_FRAC_BITS = 32
INV_LN2_Q32 = 6196328018  # q32_t
S64_MIN = -(1 << 63)

MASK64 = (1 << 64) - 1

def to_s64(x: int) -> int:
    """Wrap to signed 64-bit two's-complement."""
    x &= MASK64
    return x - (1 << 64) if x & (1 << 63) else x

def div_s64(a: int, b: int) -> int:
    """Signed division with truncation toward zero (like C)."""
    if b == 0:
        raise ZeroDivisionError
    return math.trunc(a / b)

def div_u64(a: int, b: int) -> int:
    """Unsigned (non-negative) integer division (like C)."""
    if b == 0:
        raise ZeroDivisionError
    return a // b

def ilog2_u64(x: int) -> int:
    # kernel ilog2(0) is undefined; caller avoids x==0.
    return x.bit_length() - 1

def normalize_to_q32(x: int, e: int) -> int:
    if e >= LOG2_FRAC_BITS:
        return x >> (e - LOG2_FRAC_BITS)
    else:
        return x << (LOG2_FRAC_BITS - e)

def mul_q32(a: int, b: int) -> int:
    # (a*b)>>32 with 128-bit intermediate; wrap result to s64
    return to_s64((a * b) >> LOG2_FRAC_BITS)

def log2_1p_t_q32(t_q32: int) -> int:
    t2 = mul_q32(t_q32, t_q32)
    t3 = mul_q32(t2, t_q32)
    t4 = mul_q32(t3, t_q32)
    t5 = mul_q32(t4, t_q32)
    t6 = mul_q32(t5, t_q32)

    ln1p_q32 = to_s64(
        t_q32
        - (t2 >> 1)
        + div_s64(t3, 3)
        - (t4 >> 2)
        + div_s64(t5, 5)
        - div_s64(t6, 6)
    )

    return mul_q32(ln1p_q32, INV_LN2_Q32)

def klog2_q32(x: int) -> int:
    if x == 0:
        return S64_MIN  # "minus infinity"

    e = ilog2_u64(x)
    m_q32 = normalize_to_q32(x, e)
    t_q32 = to_s64(m_q32 - (1 << LOG2_FRAC_BITS))  # m_q32 - 1.0 in Q32

    frac = log2_1p_t_q32(t_q32)
    return to_s64((e << LOG2_FRAC_BITS) + frac)

def get_logbased_pacing_rate(packet_num: int, smooth_rtt_us: int) -> int:
    if packet_num < 1:
        packet_num = 1
        
    log_np1 = klog2_q32(packet_num + 1)

    return log_np1 * smooth_rtt_us

# --- Plot demo ---
if __name__ == "__main__":
    smooth_rtt = 30_000  # 30 ms
    N = 1000

    xs = list(range(1, N + 1))
    ys = [get_logbased_pacing_rate(n, smooth_rtt) / 1000 for n in xs]

    plt.figure()
    plt.scatter(ys, xs)
    plt.title(f"Packet scheduling logarithmic pacing")
    plt.xlabel("Time since start (ms)")
    plt.ylabel("Packet number")
    plt.grid(True)
    plt.show()

# %%
import math
import matplotlib.pyplot as plt

LOG2_FRAC_BITS = 32
INV_LN2_Q32 = 6196328018
S64_MIN = -(1 << 63)
MASK64 = (1 << 64) - 1

def to_s64(x: int) -> int:
    x &= MASK64
    return x - (1 << 64) if x & (1 << 63) else x

def div_s64(a: int, b: int) -> int:
    return math.trunc(a / b)  # trunc toward zero like C

def div_u64(a: int, b: int) -> int:
    return a // b

def ilog2_u64(x: int) -> int:
    return x.bit_length() - 1

def normalize_to_q32(x: int, e: int) -> int:
    if e >= LOG2_FRAC_BITS:
        return x >> (e - LOG2_FRAC_BITS)
    else:
        return x << (LOG2_FRAC_BITS - e)

def mul_q32(a: int, b: int) -> int:
    return to_s64((a * b) >> LOG2_FRAC_BITS)

def log2_1p_t_q32(t_q32: int) -> int:
    t2 = mul_q32(t_q32, t_q32)
    t3 = mul_q32(t2, t_q32)
    t4 = mul_q32(t3, t_q32)
    t5 = mul_q32(t4, t_q32)
    t6 = mul_q32(t5, t_q32)

    ln1p_q32 = to_s64(
        t_q32
        - (t2 >> 1)
        + div_s64(t3, 3)
        - (t4 >> 2)
        + div_s64(t5, 5)
        - div_s64(t6, 6)
    )
    return mul_q32(ln1p_q32, INV_LN2_Q32)

def klog2_q32_literal(x: int) -> int:
    if x == 0:
        return S64_MIN
    e = ilog2_u64(x)
    m_q32 = normalize_to_q32(x, e)           # mantissa in [1,2) as Q32
    t_q32 = to_s64(m_q32 - (1 << 32))        # t in [0,1)
    frac = log2_1p_t_q32(t_q32)
    return to_s64((e << 32) + frac)

def klog2_q32_range_reduced(x: int) -> int:
    if x == 0:
        return S64_MIN
    e = ilog2_u64(x)
    m_q32 = normalize_to_q32(x, e)           # [1,2) in Q32

    # Range reduction: if m >= 1.5, use m/2 and bump exponent.
    # 1.5 in Q32 == 3<<31
    if m_q32 >= (3 << 31):
        m_q32 >>= 1
        e += 1

    t_q32 = to_s64(m_q32 - (1 << 32))        # now t is in roughly [-0.25, 0.5)
    frac = log2_1p_t_q32(t_q32)
    return to_s64((e << 32) + frac)

def get_rate(packet_num: int, smooth_rtt_us: int, klog2_fn) -> int:
    if packet_num < 1:
        packet_num = 1
        
    log_np1 = klog2_q32(packet_num + 1)

    return log_np1 * smooth_rtt_us

if __name__ == "__main__":
    smooth_rtt_us = 10_000
    N = 2000
    xs = list(range(1, N + 1))

    ys_literal = [get_rate(n, smooth_rtt_us, klog2_q32_literal) for n in xs]
    ys_fixed   = [get_rate(n, smooth_rtt_us, klog2_q32_range_reduced) for n in xs]

    plt.figure()
    #plt.plot(xs, ys_literal, label="literal port (your code)")
    plt.scatter(ys_fixed, xs,   label="range-reduced (fix)")
    plt.title(f"pacing rate vs packet_num (smooth_rtt_us={smooth_rtt_us})")
    plt.xlabel("packet_num")
    plt.ylabel("rate (raw integer from function)")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
import math
import matplotlib.pyplot as plt

LOG2_FRAC_BITS = 32
INV_LN2_Q32 = 6196328018
S64_MIN = -(1 << 63)
MASK64 = (1 << 64) - 1

def to_s64(x: int) -> int:
    x &= MASK64
    return x - (1 << 64) if x & (1 << 63) else x

def div_s64(a: int, b: int) -> int:
    return math.trunc(a / b)  # trunc toward zero like C

def div_u64(a: int, b: int) -> int:
    return a // b

def ilog2_u64(x: int) -> int:
    return x.bit_length() - 1

def normalize_to_q32(x: int, e: int) -> int:
    if e >= LOG2_FRAC_BITS:
        return x >> (e - LOG2_FRAC_BITS)
    else:
        return x << (LOG2_FRAC_BITS - e)

def mul_q32(a: int, b: int) -> int:
    return to_s64((a * b) >> LOG2_FRAC_BITS)

def log2_1p_t_q32(t_q32: int) -> int:
    t2 = mul_q32(t_q32, t_q32)
    t3 = mul_q32(t2, t_q32)
    t4 = mul_q32(t3, t_q32)
    t5 = mul_q32(t4, t_q32)
    t6 = mul_q32(t5, t_q32)

    ln1p_q32 = to_s64(
        t_q32
        - (t2 >> 1)
        + div_s64(t3, 3)
        - (t4 >> 2)
        + div_s64(t5, 5)
        - div_s64(t6, 6)
    )
    return mul_q32(ln1p_q32, INV_LN2_Q32)

def klog2_q32_literal(x: int) -> int:
    if x == 0:
        return S64_MIN
    e = ilog2_u64(x)
    m_q32 = normalize_to_q32(x, e)           # mantissa in [1,2) as Q32
    t_q32 = to_s64(m_q32 - (1 << 32))        # t in [0,1)
    frac = log2_1p_t_q32(t_q32)
    return to_s64((e << 32) + frac)

def klog2_q32_range_reduced(x: int) -> int:
    if x == 0:
        return S64_MIN
    e = ilog2_u64(x)
    m_q32 = normalize_to_q32(x, e)           # [1,2) in Q32

    # Range reduction: if m >= 1.5, use m/2 and bump exponent.
    # 1.5 in Q32 == 3<<31
    if m_q32 >= (3 << 31):
        m_q32 >>= 1
        e += 1

    t_q32 = to_s64(m_q32 - (1 << 32))        # now t is in roughly [-0.25, 0.5)
    frac = log2_1p_t_q32(t_q32)
    return to_s64((e << 32) + frac)

def get_rate(packet_num: int, smooth_rtt_us: int, klog2_fn) -> int:
    if packet_num < 1:
        packet_num = 1
    log_n = klog2_fn(packet_num)
    log_np1 = klog2_fn(packet_num + 1)
    delta_q32 = to_s64(log_np1 - log_n)
    if delta_q32 <= 0:
        delta_q32 = 1
    num = (1_000_000 << 32)
    num = div_u64(num, smooth_rtt_us)
    num = div_u64(num, delta_q32)
    return num

if __name__ == "__main__":
    smooth_rtt_us = 10_000
    N = 3000
    xs = list(range(1, N + 1))

    ys_literal = [get_rate(n, smooth_rtt_us, klog2_q32_literal) for n in xs]
    ys_fixed   = [get_rate(n, smooth_rtt_us, klog2_q32_range_reduced) for n in xs]

    plt.figure()
    plt.plot(xs, ys_literal, label="literal port (your code)")
    plt.plot(xs, ys_fixed,   label="range-reduced (fix)")
    plt.title(f"pacing rate vs packet_num (smooth_rtt_us={smooth_rtt_us})")
    plt.xlabel("packet_num")
    plt.ylabel("rate (raw integer from function)")
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
import math
import matplotlib.pyplot as plt

LOG2_FRAC_BITS = 32
INV_LN2_Q32 = 6196328018  # q32_t
S64_MIN = -(1 << 63)

MASK64 = (1 << 64) - 1

def to_s64(x: int) -> int:
    """Wrap to signed 64-bit two's-complement."""
    x &= MASK64
    return x - (1 << 64) if x & (1 << 63) else x

def div_s64(a: int, b: int) -> int:
    """Signed division with truncation toward zero (like C)."""
    if b == 0:
        raise ZeroDivisionError
    return math.trunc(a / b)

def ilog2_u64(x: int) -> int:
    # kernel ilog2(0) is undefined; caller avoids x==0.
    return x.bit_length() - 1

def normalize_to_q32(x: int, e: int) -> int:
    if e >= LOG2_FRAC_BITS:
        return x >> (e - LOG2_FRAC_BITS)
    else:
        return x << (LOG2_FRAC_BITS - e)

def mul_q32(a: int, b: int) -> int:
    """(a*b)>>32 with 128-bit intermediate; wrap result to s64."""
    return to_s64((a * b) >> LOG2_FRAC_BITS)

def log2_1p_t_q32(t_q32: int) -> int:
    t2 = mul_q32(t_q32, t_q32)
    t3 = mul_q32(t2, t_q32)
    t4 = mul_q32(t3, t_q32)
    t5 = mul_q32(t4, t_q32)
    t6 = mul_q32(t5, t_q32)

    ln1p_q32 = to_s64(
        t_q32
        - (t2 >> 1)
        + div_s64(t3, 3)
        - (t4 >> 2)
        + div_s64(t5, 5)
        - div_s64(t6, 6)
    )

    return mul_q32(ln1p_q32, INV_LN2_Q32)

def klog2_q32(x: int, rtt: int) -> int:
    if x == 0:
        return S64_MIN  # "minus infinity"

    e = ilog2_u64(x)
    m_q32 = normalize_to_q32(x, e)
    t_q32 = to_s64(m_q32 - (1 << LOG2_FRAC_BITS))  # m_q32 - 1.0 in Q32

    frac = log2_1p_t_q32(t_q32)
    return to_s64((e << LOG2_FRAC_BITS) + frac)

def log_normal(x: int, rtt: int):
    return math.log2(x)

def count_packets_in_last_in_interval(ys, start_time, end_time):
    counter = 0
    
    for packet in ys:
        if packet > end_time:
            break
        
        if packet >= start_time:
            counter += 1
            
    return counter

if __name__ == "__main__":
    rtt = 30_000 # 30 ms
    N = 1000
    xs = list(range(1, N + 1))

    # Plot log values only (convert Q32 to float for readability)
    ys = [(klog2_q32(x, rtt) / float(1 << LOG2_FRAC_BITS)) for x in xs]    
    ys2 = [log_normal(x, rtt) for x in xs]

    plt.figure()
    plt.scatter(xs, ys, label="Tailor series approximations")
    plt.scatter(xs, ys2, color="red", label="Python math.log2()", alpha=0.2)
    
    #plt.axvline(max(ys) - 30, linestyle="--", linewidth=2, color="green", label="30 ms before loss") 
    #plt.axvline(max(ys) - 60, linestyle="--", linewidth=2, color="black", label="60 ms before loss") # 30 ms
    #plt.axvline(max(ys), linestyle="--", linewidth=2, color="red", label="Packet loss") # 30 ms
    
    #print("Packets sent in last 30 ms: ", count_packets_in_last_in_interval(ys, max(ys)-30, max(ys)))
    #print("Packets sent in interval 60 ms to 30 ms before loss: ", count_packets_in_last_in_interval(ys, max(ys)-60, max(ys)-30))
    #print("Packets sent in interval 60 ms to 30 ms before loss: ", count_packets_in_last_in_interval(ys, max(ys)-90, max(ys)-60))
    
    plt.title("Logarithmic approximation")
    plt.legend()
    plt.xlabel("N")
    plt.ylabel("Log2(N)")
    plt.xticks(np.arange(0, 1200, 200))
    plt.grid(True)
    plt.show()
