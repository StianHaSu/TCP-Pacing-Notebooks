# %% [markdown]
# ### How the pacing is done
# Pacing is enabled in the sender with the command:
# tc qdisc replace dev [h1-eth0] root fq maxrate 10mbit

# %%
from utils.plotting import *

# %%
from experiments.packet_transmission.utils.GraphConfig import GraphConfig

INPUT_DATA_PATH = "../raw_data/"

graph = GraphConfig(INPUT_DATA_PATH+"exp_20260302-123406_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_100_run_0_zelda_10Ga_router.dmp", 
                "RENO logarithmic pacing", 
                label=None, 
                cutoff=-1, # Just use start and end instead 
                color="blue", 
                include_acks=False, 
                save_plot=True,
                tick_step_y=10,
                tick_step_x=10,
                start=0,
                end=70)


plot_packets_from_pcap_file(graph, None)
