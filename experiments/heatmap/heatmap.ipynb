# %%
from plotting import *
from data_processing import *

# %% [markdown]
# ## Logarithmic pacing

# %%
bandwidths = [50, 100, 250, 500, 750, 1000]
queues = [10, 25, 50, 75, 100, 250, 500]

result = transform_to_matrix("exp_20260305-192159_inflight-logarithmic.txt", bandwidths, queues)

percentage = get_as_percentage_matrix(result, bandwidths, queues, 30).round().astype(int)
percentage = percentage.clip(upper=100)
plot_heatmap(percentage, "Reno with logarithmic pacing")

# %% [markdown]
# ## Default pacing

# %%
bandwidths = [50, 100, 250, 500, 750, 1000]
queues = [10, 25, 50, 75, 100, 250, 500]

result = transform_to_matrix("exp_20260305-205509_inflight-default.txt", bandwidths, queues)

percentage = get_as_percentage_matrix(result, bandwidths, queues, 30).round().astype(int)
percentage = percentage.clip(upper=100)
plot_heatmap(percentage, "Reno with default pacing")
