# %% [markdown]
# # Parsing pcap files to get max flight size

# %% [markdown]
# ### Find max flight in experiments

# %%
from experiments.max_flightsize.pcap_parsing.parse_pcap_file import parse_all_in_experiment
from experiments.max_flightsize.pcap_parsing.experiment_config import ExperimentConfig

experiment_config = ExperimentConfig(
    experiment_name="exp_20260309-221153",
    bandwidths=[50, 100, 250, 500, 750, 1000],
    delay_ms=15,
    queues=[10, 25, 50, 75, 100, 250, 500],
    runs=10,
    # For the router, this would be zelda_10Ga_router.dmp, and remember to unzip the files
    pcap_suffix="ganon.dmp" 
)

parse_all_in_experiment(experiment_config)
# Out:
# reading from file ../raw_data/exp_20260309-221153/exp_20260309-221153_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_10_run_0_ganon.dmp, link-type EN10MB (Ethernet)
# dest: 10.100.21.1.X, line: 10.100.21.1.6000 line7: seq
# dest: 10.100.21.1.X, line: 10.100.24.4.57642 line7: ack
# reading from file ../raw_data/exp_20260309-221153/exp_20260309-221153_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_10_run_1_ganon.dmp, link-type EN10MB (Ethernet)
# dest: 10.100.21.1.X, line: 10.100.21.1.6000 line7: seq
# dest: 10.100.21.1.X, line: 10.100.24.4.50240 line7: ack
# reading from file ../raw_data/exp_20260309-221153/exp_20260309-221153_del_15_down_50mbit_up_50mbit_aqm_pfifo_tcp_newreno_bs_10_run_2_ganon.dmp, link-type EN10MB (Ethernet)
# dest: 10.100.21.1.X, line: 10.100.21.1.6000 line7: seq
# dest: 10.100.21.1.X, line: 10.100.24.4.41774 line7: ack
# ...
