# %% [markdown]
# ### How the pacing is done
# Pacing is enabled in the sender with the command:
# tc qdisc replace dev [h1-eth0] root fq maxrate 10mbit

# %%
from analysis.utils.plotting import *

# %%
DATA_FILES_BASE_PATH = "../data/"
GRAPH_CUTOFF = 30

graphs = [
    GraphConfig(DATA_FILES_BASE_PATH + "reno_topology1_30s.pcap", "RENO no pacing", label="No pacing", cutoff=GRAPH_CUTOFF, color="grey"),
    GraphConfig(DATA_FILES_BASE_PATH + "baseline_reno_topology1_60s.pcap", "RENO default paced", label="Default", cutoff=GRAPH_CUTOFF, color="black"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_1m_topology1_30s.pcap", "RENO custom paced", label="Custom", cutoff=GRAPH_CUTOFF, color="firebrick"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_2m_topology1_30s.pcap", "RENO custom paced x2", label="Custom x2", cutoff=GRAPH_CUTOFF, color="yellow"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_3m_topology1_30s.pcap", "RENO custom paced x3", label="Custom x3", cutoff=GRAPH_CUTOFF, color="limegreen"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_4m_topology1_30s.pcap", "RENO custom paced x4", label="Custom x4", cutoff=GRAPH_CUTOFF, color="orange"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_5m_topology1_30s.pcap", "RENO custom paced x5", label="Custom x5", cutoff=GRAPH_CUTOFF, color="cyan"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_6m_topology1_30s.pcap", "RENO custom paced x6", label="Custom x6", cutoff=GRAPH_CUTOFF, color="royalblue"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_7m_topology1_30s.pcap", "RENO custom paced x7", label="Custom x7", cutoff=GRAPH_CUTOFF, color="indigo"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_8m_topology1_30s.pcap", "RENO custom paced x8", label="Custom x8", cutoff=GRAPH_CUTOFF, color="deeppink"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_9m_topology1_30s.pcap", "RENO custom paced x9", label="Custom x9", cutoff=GRAPH_CUTOFF, color="gold"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_10m_topology1_30s.pcap", "RENO custom paced x10", label="Custom x10", cutoff=GRAPH_CUTOFF, color="peru"),
]

graphs = plot_packets_from_pcap_files(graphs, cutoff=GRAPH_CUTOFF)
graphs_mapped = { graph[0].title : graph for graph in graphs }

# %%
GRAPH_CUTOFF = 100

plot_packets_from_pcap_files(graphs, list(graphs_mapped.values()), cutoff=GRAPH_CUTOFF)
# Out:
# [(<analysis.utils.GraphConfig.GraphConfig at 0x12888b190>,
#   <analysis.utils.GraphData.GraphData at 0x1233e17d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e2d3f50>,
#   <analysis.utils.GraphData.GraphData at 0x1595236d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e2d2890>,
#   <analysis.utils.GraphData.GraphData at 0x149334a50>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x121340c50>,
#   <analysis.utils.GraphData.GraphData at 0x123701dd0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13921a610>,
#   <analysis.utils.GraphData.GraphData at 0x121af1d50>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x12011a3d0>,
#   <analysis.utils.GraphData.GraphData at 0x124729290>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e28bfd0>,
#   <analysis.utils.GraphData.GraphData at 0x122a77810>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e28a710>,
#   <analysis.utils.GraphData.GraphData at 0x1242f4d10>),
# ...

# %%
GRAPH_CUTOFF = 1000

plot_packets_from_pcap_files(graphs, list(graphs_mapped.values()), cutoff=GRAPH_CUTOFF)
# Out:
# [(<analysis.utils.GraphConfig.GraphConfig at 0x12888b190>,
#   <analysis.utils.GraphData.GraphData at 0x1233e17d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e2d3f50>,
#   <analysis.utils.GraphData.GraphData at 0x1595236d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e2d2890>,
#   <analysis.utils.GraphData.GraphData at 0x149334a50>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x121340c50>,
#   <analysis.utils.GraphData.GraphData at 0x123701dd0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13921a610>,
#   <analysis.utils.GraphData.GraphData at 0x121af1d50>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x12011a3d0>,
#   <analysis.utils.GraphData.GraphData at 0x124729290>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e28bfd0>,
#   <analysis.utils.GraphData.GraphData at 0x122a77810>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e28a710>,
#   <analysis.utils.GraphData.GraphData at 0x1242f4d10>),
# ...

# %%
GRAPH_CUTOFF = 10000

plot_packets_from_pcap_files(graphs, list(graphs_mapped.values()), cutoff=GRAPH_CUTOFF)
# Out:
# [(<analysis.utils.GraphConfig.GraphConfig at 0x12888b190>,
#   <analysis.utils.GraphData.GraphData at 0x1233e17d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e2d3f50>,
#   <analysis.utils.GraphData.GraphData at 0x1595236d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e2d2890>,
#   <analysis.utils.GraphData.GraphData at 0x149334a50>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x121340c50>,
#   <analysis.utils.GraphData.GraphData at 0x123701dd0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13921a610>,
#   <analysis.utils.GraphData.GraphData at 0x121af1d50>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x12011a3d0>,
#   <analysis.utils.GraphData.GraphData at 0x124729290>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e28bfd0>,
#   <analysis.utils.GraphData.GraphData at 0x122a77810>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e28a710>,
#   <analysis.utils.GraphData.GraphData at 0x1242f4d10>),
# ...

# %%
GRAPH_CUTOFF = 100

graphs_calculated = [graphs_mapped["RENO default paced"], graphs_mapped["RENO custom paced x10"], graphs_mapped["RENO no pacing"]] 

plot_packets_from_pcap_files(graphs, graphs_calculated, cutoff=GRAPH_CUTOFF)
# Out:
# [(<analysis.utils.GraphConfig.GraphConfig at 0x13e2d3f50>,
#   <analysis.utils.GraphData.GraphData at 0x1595236d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e289690>,
#   <analysis.utils.GraphData.GraphData at 0x120bef390>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x12888b190>,
#   <analysis.utils.GraphData.GraphData at 0x1233e17d0>)]

# %%
GRAPH_CUTOFF = 100

graphs_calculated = [graphs_mapped["RENO default paced"], graphs_mapped["RENO custom paced x10"], graphs_mapped["RENO no pacing"]] 

plot_packets_from_pcap_files(graphs, graphs_calculated, cutoff=GRAPH_CUTOFF)
# Out:
# [(<analysis.utils.GraphConfig.GraphConfig at 0x13e2d3f50>,
#   <analysis.utils.GraphData.GraphData at 0x1595236d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e289690>,
#   <analysis.utils.GraphData.GraphData at 0x120bef390>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x12888b190>,
#   <analysis.utils.GraphData.GraphData at 0x1233e17d0>)]

# %%
GRAPH_CUTOFF = 500

graphs_calculated = [graphs_mapped["RENO default paced"], graphs_mapped["RENO custom paced x10"], graphs_mapped["RENO no pacing"]] 

plot_packets_from_pcap_files(graphs, graphs_calculated, cutoff=GRAPH_CUTOFF)
# Out:
# [(<analysis.utils.GraphConfig.GraphConfig at 0x13e2d3f50>,
#   <analysis.utils.GraphData.GraphData at 0x1595236d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e289690>,
#   <analysis.utils.GraphData.GraphData at 0x120bef390>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x12888b190>,
#   <analysis.utils.GraphData.GraphData at 0x1233e17d0>)]

# %%
GRAPH_CUTOFF = 100

graphs_calculated = [graphs_mapped["RENO default paced"], graphs_mapped["RENO custom paced"], graphs_mapped["RENO custom paced x10"], graphs_mapped["RENO no pacing"]] 

plot_packets_from_pcap_files(graphs, graphs_calculated, cutoff=GRAPH_CUTOFF)
# Out:
# [(<analysis.utils.GraphConfig.GraphConfig at 0x13e2d3f50>,
#   <analysis.utils.GraphData.GraphData at 0x1595236d0>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e2d2890>,
#   <analysis.utils.GraphData.GraphData at 0x149334a50>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x13e289690>,
#   <analysis.utils.GraphData.GraphData at 0x120bef390>),
#  (<analysis.utils.GraphConfig.GraphConfig at 0x12888b190>,
#   <analysis.utils.GraphData.GraphData at 0x1233e17d0>)]

# %%
GRAPH_CUTOFF = 200

topology_two = [
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_10m_topology2_sender1_30s.pcap", "RENO custom paced x10", label="Sender 1 Custom x10", cutoff=GRAPH_CUTOFF, color="red"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_10m_topology2_sender2_30s.pcap", "RENO custom paced x10", label="Sender 2 Custom x10", cutoff=GRAPH_CUTOFF, color="blue"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_5m_topology2_sender1_30s.pcap", "RENO custom paced x5", label="Sender 1 Custom x5", cutoff=GRAPH_CUTOFF, color="green"),
    GraphConfig(DATA_FILES_BASE_PATH + "6.12.1035_reno_5m_topology2_sender2_30s.pcap", "RENO custom paced x5", label="Sender 2 Custom x5", cutoff=GRAPH_CUTOFF, color="purple")
]

graphs2 = plot_packets_from_pcap_files(topology_two, cutoff=GRAPH_CUTOFF)
